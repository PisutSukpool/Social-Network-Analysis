# %% [markdown]
# <a href="https://colab.research.google.com/github/PisutSukpool/BADS/blob/main/Homework%2003/6210422044_PisutSukpool_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyxlsb

# %%
import requests
from bs4 import BeautifulSoup
url = requests.get('https://github.com/PisutSukpool/BADS7105-CRM-analytics-and-intelligence/tree/main/Homework%2003/Dataset')
soup = BeautifulSoup(url.content, 'html.parser')
div = soup.findAll("span",{"class": "css-truncate css-truncate-target d-block width-fit"})
file_name = []
for i in div:
  if str(i).find('>ac') == -1 and str(i).find('readme') == -1:
    file_name.append(str(i)[str(i).find('>Ac')+1:str(i).find('</a>')])
  elif str(i).find('>ac') != -1 and str(i).find('readme') == -1:
    file_name.append(str(i)[str(i).find('>ac')+1:str(i).find('</a>')])
  else:
    pass

# %%
import pandas as pd
cnt=0
df=pd.DataFrame()
for f in file_name:
  f= f.replace(' ','%20')
  try:
    df2 = pd.read_excel('https://github.com/PisutSukpool/BADS7105-CRM-analytics-and-intelligence/raw/main/Homework%2003/Dataset/'+f,names=['Time','Activity','Pain','Gain'])
  except:
    df2 = pd.read_excel('https://github.com/PisutSukpool/BADS7105-CRM-analytics-and-intelligence/raw/main/Homework%2003/Dataset/'+f, engine='pyxlsb',names=['Time','Activity','Pain','Gain'])
  df = df.append(df2)
df.head(25)
# Out:
#         Time  ...                                Gain
# 0   08:30:00  ...                  ได้เริ่มต้นวันใหม่
# 1   08:35:00  ...                        สดชื่น+สะอาด
# 2   09:00:00  ...                            อิ่มท้อง
# 3   10:00:00  ...                    เดินทางสะดวกสบาย
# 4   10:30:00  ...         เป็นช่วงที่พร้อมทำงานที่สุด
# 5   13:00:00  ...          พักจากการทำงาน และอิ่มท้อง
# 6   13:45:00  ...  รู้สึกตื่นพร้อมทำงานสำหรับช่วงบ่าย
# 7   14:00:00  ...    ได้เริ่มทำงานที่ค้างอยู่ให้เสร็จ
# 8   15:15:00  ...              สรุปงานที่จะทำประจำวัน
# 9   15:45:00  ...            สรุปรายละเอียดระหว่างทีม
# 10  19:15:00  ...    รู้ความคืบหน้าและปัญหาในแต่ละวัน
# 11  19:30:00  ...           ออกจาก office กลับบ้านได้
# 12  19:30:00  ...                    เดินทางสะดวกสบาย
# 13  20:00:00  ...                            อิ่มท้อง
# 14  21:00:00  ...                        สดชื่น+สะอาด
# 15  21:30:00  ...                     ได้ความรู้ใหม่ๆ
# 16  22:30:00  ...                          ได้พักผ่อน
# 17  00:00:00  ...                                 NaN
# 0   07:30:00  ...                    ไดพักผ่อนเต็มที่
# 1   08:00:00  ...                      สดชื่น ตื่นตัว
# 2   08:30:00  ...                         ภาพลักษณ์ดี
# 3   09:00:00  ...              ถึงที่ทำงานก่อนเวลางาน
# 4   09:15:00  ...                     สาวๆให้ส่องเยอะ
# 5   09:30:00  ...                                อิ่ม
# 6   09:45:00  ...             ตื่นตัวเมื่อได้ดื่มกาแฟ
#
# [25 rows x 4 columns]
